# %%
# !rm -rf .ipynb_checkpoints .Trash-0
# Out:
# .	  .ipynb_checkpoints			       distilbert-local-base
# ..	  C2_M3_Lab_4_finetuned_text_classifier.ipynb  helper_utils.py
# .Trash-0  Untitled.ipynb			       recipes_fruit_veg.csv

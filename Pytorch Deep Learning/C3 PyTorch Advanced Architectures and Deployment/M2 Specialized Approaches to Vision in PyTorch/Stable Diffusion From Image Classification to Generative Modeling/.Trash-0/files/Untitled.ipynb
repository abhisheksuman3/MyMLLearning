# %%
# !ls -a
# Out:
# .	  .ipynb_checkpoints		      helper_utils.py
# ..	  C3_M2_Lab_3_stable_diffusion.ipynb  intermediate_steps
# .Trash-0  Untitled.ipynb		      models

# %%
# !rm -rf .ipynb_checkpoints intermediate_steps .Trash-0 Untitled.ipynb

# %%
# import os
# import zipfile
# from tqdm.auto import tqdm

# def create_model_snapshot_zip():
#     """
#     Creates a zip archive of the snapshot directory.

#     Locates the source directory containing model snapshots and compresses
#     its contents into a zip file at the same base path. This function is
#     intended for creating portable archives of the model weights.
#     """
#     # Define base paths for the source directory and destination zip file
#     base_path = "./models/models--google--ddpm-ema-bedroom-256/"
#     snapshot_dir = os.path.join(base_path, "snapshots")
#     zip_path = os.path.join(base_path, "snapshots.zip")

#     # Verify that the source directory exists before attempting to zip
#     if not os.path.exists(snapshot_dir):
#         raise FileNotFoundError(f"Source directory not found at: {snapshot_dir}")

#     print(f"Prepare to zip directory: {snapshot_dir}")

#     # Initialize the zip file in write mode with compression
#     with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
#         # Walk through the directory structure to find all files
#         for root, _, files in os.walk(snapshot_dir):
#             for file in tqdm(files, desc="Zipping", unit="file"):
#                 # Construct the full file path
#                 file_path = os.path.join(root, file)
                
#                 # Determine the relative path inside the zip archive
#                 # This ensures the zip structure mirrors the folder structure relative to the base
#                 arcname = os.path.relpath(file_path, base_path)
                
#                 # Write the file to the zip archive
#                 zipf.write(file_path, arcname)

#     print(f"Compression complete. Archive saved to: {zip_path}")

# %%
# create_model_snapshot_zip()
